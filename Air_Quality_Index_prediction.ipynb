# %% [markdown]
# <a href="https://colab.research.google.com/github/ashunni99/Datasets/blob/main/Air_Quality_Index_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Air Quality Index Prediction**

# %% [markdown]
# Importing necessary Libraries and the required dataset

# %%
import numpy as np
import pandas as pd

df=pd.read_csv('/content/data_date.csv')
df
# Out:
#              Date     Country                          Status  AQI Value
# 0      2022-07-21     Albania                            Good         14
# 1      2022-07-21     Algeria                        Moderate         65
# 2      2022-07-21     Andorra                        Moderate         55
# 3      2022-07-21      Angola  Unhealthy for Sensitive Groups        113
# 4      2022-07-21   Argentina                        Moderate         63
# ...           ...         ...                             ...        ...
# 12981  2023-08-10  Uzbekistan                            Good         28
# 12982  2023-08-10     Vatican                            Good         34
# 12983  2023-08-10   Venezuela                            Good         26
# 12984  2023-08-10     Vietnam  Unhealthy for Sensitive Groups        142
# 12985  2023-08-10      Zambia                        Moderate         79
#
# [12986 rows x 4 columns]

# %% [markdown]
# Checking for the datatypes

# %%
df.dtypes
# Out:
# Date         object
# Country      object
# Status       object
# AQI Value     int64
# dtype: object

# %% [markdown]
# Checking for missing values if any

# %%
df.isna().sum()
# Out:
# Date         0
# Country      0
# Status       0
# AQI Value    0
# dtype: int64

# %% [markdown]
# Changing the format of date to numerical value

# %%
df['Date']=pd.to_datetime(df['Date'])

# %% [markdown]
# Again checking for the datatypes

# %%
df.dtypes
# Out:
# Date         datetime64[ns]
# Country              object
# Status               object
# AQI Value             int64
# dtype: object

# %% [markdown]
# Creating seperate columns for year,month,day

# %%
df['year']=df['Date'].dt.year
df['month']=df['Date'].dt.month
df['day']=df['Date'].dt.day

# %% [markdown]
# Printing df

# %%
df
# Out:
#             Date     Country                          Status  AQI Value  year  \
# 0     2022-07-21     Albania                            Good         14  2022
# 1     2022-07-21     Algeria                        Moderate         65  2022
# 2     2022-07-21     Andorra                        Moderate         55  2022
# 3     2022-07-21      Angola  Unhealthy for Sensitive Groups        113  2022
# 4     2022-07-21   Argentina                        Moderate         63  2022
# ...          ...         ...                             ...        ...   ...
# 12981 2023-08-10  Uzbekistan                            Good         28  2023
# 12982 2023-08-10     Vatican                            Good         34  2023
# 12983 2023-08-10   Venezuela                            Good         26  2023
# 12984 2023-08-10     Vietnam  Unhealthy for Sensitive Groups        142  2023
# 12985 2023-08-10      Zambia                        Moderate         79  2023
#
#        month  day
# ...

# %% [markdown]
# Now, again checking for datatypes

# %%
df.dtypes
# Out:
# Date         datetime64[ns]
# Country              object
# Status               object
# AQI Value             int64
# year                  int64
# month                 int64
# day                   int64
# dtype: object

# %% [markdown]
# Droping the Date column from the dataset

# %%
df=df.drop(['Date'],axis=1)

# %% [markdown]
# Printing df

# %%
df
# Out:
#           Country                          Status  AQI Value  year  month  day
# 0         Albania                            Good         14  2022      7   21
# 1         Algeria                        Moderate         65  2022      7   21
# 2         Andorra                        Moderate         55  2022      7   21
# 3          Angola  Unhealthy for Sensitive Groups        113  2022      7   21
# 4       Argentina                        Moderate         63  2022      7   21
# ...           ...                             ...        ...   ...    ...  ...
# 12981  Uzbekistan                            Good         28  2023      8   10
# 12982     Vatican                            Good         34  2023      8   10
# 12983   Venezuela                            Good         26  2023      8   10
# 12984     Vietnam  Unhealthy for Sensitive Groups        142  2023      8   10
# 12985      Zambia                        Moderate         79  2023      8   10
#
# ...

# %% [markdown]
# Performing Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
df['Country']=lb.fit_transform(df['Country'])
df['Status']=lb.fit_transform(df['Status'])

# %% [markdown]
# Checking for the datatypes after performing Encoding

# %%
df.dtypes
# Out:
# Country      int64
# Status       int64
# AQI Value    int64
# year         int64
# month        int64
# day          int64
# dtype: object

# %% [markdown]
# Seperating 'x' and 'y' columns from the dataset

# %%
x=df.drop(['Status'],axis=1).values
y=df['Status'].values

# %% [markdown]
# Performing train_test_split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)

# %% [markdown]
# Performing Normalization Technique

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(x_train)
x_train=scaler.transform(x_train)
x_test=scaler.transform(x_test)

# %% [markdown]
# Creating a model using Naive Bayes Algorithm

# %%
from sklearn.naive_bayes import BernoulliNB
model=BernoulliNB()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)

# %% [markdown]
# Printing accuracy score for the above created model

# %%
from sklearn.metrics import accuracy_score
ac=accuracy_score(y_test,y_pred)

# %%
print("Accuracy Score for the model is =",ac)
# Out:
# Accuracy Score for the model is = 0.747946611909651
